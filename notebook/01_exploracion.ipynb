# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Cargar el dataset
df = pd.read_csv("../data/weather_aus.csv")

df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0           W           44.0          W  ...        22.0       1007.7
# 1         WNW           44.0        NNW  ...        25.0       1010.6
# 2         WSW           46.0          W  ...        30.0       1007.6
# 3          NE           24.0         SE  ...        16.0       1017.6
# 4           W           41.0        ENE  ...        33.0       1010.8
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# ...

# %%
import kedro
# %matplotlib inline     
sns.set(color_codes=True)
print(kedro.__version__)
# Out:
# 0.19.12

# %%
df.shape
# Out:
# (142193, 24)

# %%
df.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
df.head(100)
# Out:
#           Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0   2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1   2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2   2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3   2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4   2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# ..         ...      ...      ...      ...       ...          ...       ...
# 95  2009-03-07   Albury      8.3     27.9       0.0          NaN       NaN
# 96  2009-03-08   Albury     11.0     30.2       0.0          NaN       NaN
# 97  2009-03-09   Albury     13.8     31.8       0.0          NaN       NaN
# 98  2009-03-10   Albury     15.5     32.0       0.0          NaN       NaN
# 99  2009-03-11   Albury     18.4     30.5       1.2          NaN       NaN
#
# ...

# %%
df.head(142193)
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 142188  2017-06-20    Uluru      3.5     21.8       0.0          NaN
# 142189  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 142190  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 142191  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 142192  2017-06-24    Uluru      7.8     27.0       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  \
# ...

# %%
df.tail(100)
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 142093  2017-03-17    Uluru     19.8     37.7       0.0          NaN
# 142094  2017-03-18    Uluru     20.3     38.8       0.0          NaN
# 142095  2017-03-19    Uluru     19.2     39.5       0.0          NaN
# 142096  2017-03-20    Uluru     17.5     39.7       0.0          NaN
# 142097  2017-03-21    Uluru     21.8     38.9       0.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 142188  2017-06-20    Uluru      3.5     21.8       0.0          NaN
# 142189  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 142190  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 142191  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 142192  2017-06-24    Uluru      7.8     27.0       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  \
# ...

# %%
df.sample(10)
# Out:
#               Date       Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 73355   2010-08-24       Portland      5.2     11.5       6.6          2.0
# 48552   2011-02-15    Tuggeranong     12.6     23.2       0.0          NaN
# 53752   2009-02-17       Ballarat     12.7     29.1       0.0          NaN
# 99588   2016-05-24   MountGambier      8.5     18.1       3.6          NaN
# 21766   2012-03-25  NorfolkIsland     20.2     23.6       0.6          3.2
# 116484  2014-02-19   PerthAirport     17.3     36.7       0.0         12.0
# 49042   2012-07-21    Tuggeranong     -3.8     13.8       0.0          NaN
# 32839   2009-01-06  SydneyAirport     19.9     29.7       0.0         10.0
# 10567   2013-09-30   CoffsHarbour     12.1     28.4       0.0          5.4
# 121741  2011-07-05     SalmonGums      2.6     14.4       0.4          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  \
# ...

# %%
df.tail(10)
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 142183  2017-06-15    Uluru      2.6     22.5       0.0          NaN
# 142184  2017-06-16    Uluru      5.2     24.3       0.0          NaN
# 142185  2017-06-17    Uluru      6.4     23.4       0.0          NaN
# 142186  2017-06-18    Uluru      8.0     20.7       0.0          NaN
# 142187  2017-06-19    Uluru      7.4     20.6       0.0          NaN
# 142188  2017-06-20    Uluru      3.5     21.8       0.0          NaN
# 142189  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 142190  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 142191  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 142192  2017-06-24    Uluru      7.8     27.0       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  \
# 142183       NaN           S           19.0          S  ...        24.0
# ...

# %%
df.head(10)
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# 5  2008-12-06   Albury     14.6     29.7       0.2          NaN       NaN
# 6  2008-12-07   Albury     14.3     25.0       0.0          NaN       NaN
# 7  2008-12-08   Albury      7.7     26.7       0.0          NaN       NaN
# 8  2008-12-09   Albury      9.7     31.9       0.0          NaN       NaN
# 9  2008-12-10   Albury     13.1     30.1       1.4          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0           W           44.0          W  ...        22.0       1007.7
# ...
